# %%
import MVTecAD_loaddata as mv
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import csv
import tensorflow as tf
import sklearn
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import OneClassSVM
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score
import cv2
import pandas as pd
from PIL import Image

# %%
def OCSVM(X, x_test, y, y_test):
    tuned_parameters = [
        {'nu': [2**-3, 2**-4, 2**-5, 2**-6], 'kernel': ['rbf'], 'gamma': [10**-4, 10**-5, 10**-6]},
    ]
    score = 'roc_auc_ovr_weighted'
    clf = GridSearchCV(
        OneClassSVM(),
        tuned_parameters,
        cv=5,
        scoring=score)
    clf.fit(X, y)
    a = clf.decision_function(x_test)
    b = clf.predict(x_test)
    r1 = roc_auc_score(y_test,a)
    r2 = f1_score(y_test,b)
    r3 = accuracy_score(y_test,b)
    print('roc_auc : ',r1)
    print('f1_score : ', r2)
    print('accuracy_score : ', r3)
    print('best_params : ', clf.best_params_)
    result = [r1,r2,r3]
    return result

def fimage_bottle(X):
    data = []
    for i in range(len(X)):
        img = cv2.imread('mask/bottle/'+str(i)+'.png')
        img = list(img)
        data.append(img)
    data = np.array(data)
    return data

def fimage_cable(X):
    data = []
    for i in range(len(X)):
        img = cv2.imread('mask/cable/'+str(i)+'.png')
        img = list(img)
        data.append(img)
    data = np.array(data)
    return data     

def fimage_capsule(X):
    data = []
    for i in range(len(X)):
        img = cv2.imread('mask/capsule/'+str(i)+'.png')
        img = list(img)
        data.append(img)
    data = np.array(data)
    return data     

def fimage_hazelnut(X):
    data = []
    for i in range(len(X)):
        img = cv2.imread('mask/hazelnut/'+str(i)+'.png')
        img = list(img)
        data.append(img)
    data = np.array(data)
    return data     

def fimage_metal_nut(X):
    data = []
    for i in range(len(X)):
        img = cv2.imread('mask/metal-nut/'+str(i)+'.png')
        img = list(img)
        data.append(img)
    data = np.array(data)
    return data     

def fimage_pill(X):
    data = []
    for i in range(len(X)):
        img = cv2.imread('mask/pill/'+str(i)+'.png')
        img = list(img)
        data.append(img)
    data = np.array(data)
    return data     

def fimage_screw(X):
    data = []
    for i in range(len(X)):
        img = cv2.imread('mask/screw/'+str(i)+'.png')
        img = list(img)
        data.append(img)
    data = np.array(data)
    return data     

def fimage_toothbrush(X):
    data = []
    for i in range(len(X)):
        img = cv2.imread('mask/toothbrush/'+str(i)+'.png')
        img = list(img)
        data.append(img)
    data = np.array(data)
    return data     

def fimage_transistor(X):
    data = []
    for i in range(len(X)):
        img = cv2.imread('mask/transistor/'+str(i)+'.png')
        img = list(img)
        data.append(img)
    data = np.array(data)
    return data     

def fimage_zipper(X):
    data = []
    for i in range(len(X)):
        img = cv2.imread('mask/zipper/'+str(i)+'.png')
        img = list(img)
        data.append(img)
    data = np.array(data)
    return data

# def fimage_bottle(X):
#     data = []
#     for i in range(len(X)):
#         img = cv2.imread('fakes/bottle/'+str(i)+'.png')
#         img = list(img)
#         data.append(img)
#     data = np.array(data)
#     return data

# def fimage_cable(X):
#     data = []
#     for i in range(len(X)):
#         img = cv2.imread('fakes/cable/'+str(i)+'.png')
#         img = list(img)
#         data.append(img)
#     data = np.array(data)
#     return data     

# def fimage_capsule(X):
#     data = []
#     for i in range(len(X)):
#         img = cv2.imread('fakes/capsule/'+str(i)+'.png')
#         img = list(img)
#         data.append(img)
#     data = np.array(data)
#     return data     

# def fimage_hazelnut(X):
#     data = []
#     for i in range(len(X)):
#         img = cv2.imread('fakes/hazelnut/'+str(i)+'.png')
#         img = list(img)
#         data.append(img)
#     data = np.array(data)
#     return data     

# def fimage_metal_nut(X):
#     data = []
#     for i in range(len(X)):
#         img = cv2.imread('fakes/metal-nut/'+str(i)+'.png')
#         img = list(img)
#         data.append(img)
#     data = np.array(data)
#     return data     

# def fimage_pill(X):
#     data = []
#     for i in range(len(X)):
#         img = cv2.imread('fakes/pill/'+str(i)+'.png')
#         img = list(img)
#         data.append(img)
#     data = np.array(data)
#     return data     

# def fimage_screw(X):
#     data = []
#     for i in range(len(X)):
#         img = cv2.imread('fakes/screw/'+str(i)+'.png')
#         img = list(img)
#         data.append(img)
#     data = np.array(data)
#     return data     

# def fimage_toothbrush(X):
#     data = []
#     for i in range(len(X)):
#         img = cv2.imread('fakes/toothbrush/'+str(i)+'.png')
#         img = list(img)
#         data.append(img)
#     data = np.array(data)
#     return data     

# def fimage_transistor(X):
#     data = []
#     for i in range(len(X)):
#         img = cv2.imread('fakes/transistor/'+str(i)+'.png')
#         img = list(img)
#         data.append(img)
#     data = np.array(data)
#     return data     

# def fimage_zipper(X):
#     data = []
#     for i in range(len(X)):
#         img = cv2.imread('fakes/zipper/'+str(i)+'.png')
#         img = list(img)
#         data.append(img)
#     data = np.array(data)
#     return data

res = []

# %%
X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.bottle()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.cable()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.capsule()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.hazelnut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.metal_nut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.pill()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.screw()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.toothbrush()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.transistor()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.zipper()

im = fimage_bottle(X_train)
im = im[:int(len(X_train)*0.125)]/255
x_train = np.concatenate([X_train, im])
y_train = []
for i in range(len(im)):
    y_train.append(-1)
y_train = np.array(y_train)
y_train = y_train.reshape([len(y_train), 1])
labels = np.concatenate([y_tr, y_train])
x_train = np.reshape(x_train, (len(x_train), -1))
x_test = np.reshape(X_test, (len(X_test), -1))
result = OCSVM(x_train, x_test, labels, y_ts)
res.append(result)
# Out:
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# roc_auc :  0.8277777777777778
# f1_score :  0.47619047619047616
# accuracy_score :  0.46987951807228917
# best_params :  {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.125}

# %%
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.bottle()
X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.cable()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.capsule()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.hazelnut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.metal_nut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.pill()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.screw()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.toothbrush()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.transistor()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.zipper()

im = fimage_cable(X_train)
im = im[:int(len(X_train)*0.125)]/255
x_train = np.concatenate([X_train, im])
y_train = []
for i in range(len(im)):
    y_train.append(-1)
y_train = np.array(y_train)
y_train = y_train.reshape([len(y_train), 1])
labels = np.concatenate([y_tr, y_train])
x_train = np.reshape(x_train, (len(x_train), -1))
x_test = np.reshape(X_test, (len(X_test), -1))
result = OCSVM(x_train, x_test, labels, y_ts)
res.append(result)
# Out:
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# roc_auc :  0.6865012615643398
# f1_score :  0.6473988439306358
# accuracy_score :  0.5642857142857143
# best_params :  {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.125}

# %%
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.bottle()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.cable()
X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.capsule()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.hazelnut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.metal_nut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.pill()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.screw()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.toothbrush()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.transistor()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.zipper()

im = fimage_capsule(X_train)
im = im[:int(len(X_train)*0.125)]/255
x_train = np.concatenate([X_train, im])
y_train = []
for i in range(len(im)):
    y_train.append(-1)
y_train = np.array(y_train)
y_train = y_train.reshape([len(y_train), 1])
labels = np.concatenate([y_tr, y_train])
x_train = np.reshape(x_train, (len(x_train), -1))
x_test = np.reshape(X_test, (len(X_test), -1))
result = OCSVM(x_train, x_test, labels, y_ts)
res.append(result)
# Out:
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# roc_auc :  0.49940167530913443
# f1_score :  0.2916666666666667
# accuracy_score :  0.22727272727272727
# best_params :  {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.125}

# %%
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.bottle()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.cable()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.capsule()
X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.hazelnut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.metal_nut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.pill()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.screw()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.toothbrush()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.transistor()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.zipper()

im = fimage_hazelnut(X_train)
im = im[:int(len(X_train)*0.125)]/255
x_train = np.concatenate([X_train, im])
y_train = []
for i in range(len(im)):
    y_train.append(-1)
y_train = np.array(y_train)
y_train = y_train.reshape([len(y_train), 1])
labels = np.concatenate([y_tr, y_train])
x_train = np.reshape(x_train, (len(x_train), -1))
x_test = np.reshape(X_test, (len(X_test), -1))
result = OCSVM(x_train, x_test, labels, y_ts)
res.append(result)
# Out:
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# roc_auc :  0.8271428571428572
# f1_score :  0.5714285714285715
# accuracy_score :  0.45454545454545453
# best_params :  {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.125}

# %%
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.bottle()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.cable()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.capsule()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.hazelnut()
X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.metal_nut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.pill()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.screw()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.toothbrush()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.transistor()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.zipper()

im = fimage_metal_nut(X_train)
im = im[:int(len(X_train)*0.125)]/255
x_train = np.concatenate([X_train, im])
y_train = []
for i in range(len(im)):
    y_train.append(-1)
y_train = np.array(y_train)
y_train = y_train.reshape([len(y_train), 1])
labels = np.concatenate([y_tr, y_train])
x_train = np.reshape(x_train, (len(x_train), -1))
x_test = np.reshape(X_test, (len(X_test), -1))
result = OCSVM(x_train, x_test, labels, y_ts)
res.append(result)
# Out:
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# roc_auc :  0.3763440860215054
# f1_score :  0.32116788321167883
# accuracy_score :  0.19130434782608696
# best_params :  {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.125}

# %%
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.bottle()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.cable()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.capsule()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.hazelnut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.metal_nut()
X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.pill()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.screw()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.toothbrush()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.transistor()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.zipper()

im = fimage_pill(X_train)
im = im[:int(len(X_train)*0.125)]/255
x_train = np.concatenate([X_train, im])
y_train = []
for i in range(len(im)):
    y_train.append(-1)
y_train = np.array(y_train)
y_train = y_train.reshape([len(y_train), 1])
labels = np.concatenate([y_tr, y_train])
x_train = np.reshape(x_train, (len(x_train), -1))
x_test = np.reshape(X_test, (len(X_test), -1))
result = OCSVM(x_train, x_test, labels, y_ts)
res.append(result)
# Out:
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# roc_auc :  0.6590289143480632
# f1_score :  0.27807486631016043
# accuracy_score :  0.19161676646706588
# best_params :  {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.125}

# %%
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.bottle()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.cable()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.capsule()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.hazelnut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.metal_nut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.pill()
X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.screw()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.toothbrush()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.transistor()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.zipper()

im = fimage_screw(X_train)
im = im[:int(len(X_train)*0.125)]/255
x_train = np.concatenate([X_train, im])
y_train = []
for i in range(len(im)):
    y_train.append(-1)
y_train = np.array(y_train)
y_train = y_train.reshape([len(y_train), 1])
labels = np.concatenate([y_tr, y_train])
x_train = np.reshape(x_train, (len(x_train), -1))
x_test = np.reshape(X_test, (len(X_test), -1))
result = OCSVM(x_train, x_test, labels, y_ts)
res.append(result)
# Out:
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# roc_auc :  0.059438409510145514
# f1_score :  0.15384615384615385
# accuracy_score :  0.10625
# best_params :  {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.125}

# %%
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.bottle()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.cable()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.capsule()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.hazelnut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.metal_nut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.pill()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.screw()
X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.toothbrush()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.transistor()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.zipper()

im = fimage_toothbrush(X_train)
im = im[:int(len(X_train)*0.125)]/255
x_train = np.concatenate([X_train, im])
y_train = []
for i in range(len(im)):
    y_train.append(-1)
y_train = np.array(y_train)
y_train = y_train.reshape([len(y_train), 1])
labels = np.concatenate([y_tr, y_train])
x_train = np.reshape(x_train, (len(x_train), -1))
x_test = np.reshape(X_test, (len(X_test), -1))
result = OCSVM(x_train, x_test, labels, y_ts)
res.append(result)
# Out:
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# roc_auc :  0.7166666666666667
# f1_score :  0.55
# accuracy_score :  0.5714285714285714
# best_params :  {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.125}

# %%
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.bottle()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.cable()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.capsule()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.hazelnut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.metal_nut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.pill()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.screw()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.toothbrush()
X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.transistor()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.zipper()

im = fimage_transistor(X_train)
im = im[:int(len(X_train)*0.125)]/255
x_train = np.concatenate([X_train, im])
y_train = []
for i in range(len(im)):
    y_train.append(-1)
y_train = np.array(y_train)
y_train = y_train.reshape([len(y_train), 1])
labels = np.concatenate([y_tr, y_train])
x_train = np.reshape(x_train, (len(x_train), -1))
x_test = np.reshape(X_test, (len(X_test), -1))
result = OCSVM(x_train, x_test, labels, y_ts)
res.append(result)
# Out:
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# roc_auc :  0.6875
# f1_score :  0.7763157894736841
# accuracy_score :  0.66
# best_params :  {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.125}

# %%
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.bottle()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.cable()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.capsule()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.hazelnut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.metal_nut()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.pill()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.screw()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.toothbrush()
# X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.transistor()
X_train, X_test, X_test_good, X_test_error, y_tr, y_tg, y_te, y_ts = mv.zipper()

im = fimage_zipper(X_train)
im = im[:int(len(X_train)*0.125)]/255
x_train = np.concatenate([X_train, im])
y_train = []
for i in range(len(im)):
    y_train.append(-1)
y_train = np.array(y_train)
y_train = y_train.reshape([len(y_train), 1])
labels = np.concatenate([y_tr, y_train])
x_train = np.reshape(x_train, (len(x_train), -1))
x_test = np.reshape(X_test, (len(X_test), -1))
result = OCSVM(x_train, x_test, labels, y_ts)
res.append(result)
# Out:
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 298, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#   File "C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 68, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
# AttributeError: 'OneClassSVM' object has no attribute 'predict_proba'
#
#   warnings.warn(
# C:\Users\Shuta Tsuchio\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# roc_auc :  0.5714285714285715
# f1_score :  0.34090909090909094
# accuracy_score :  0.23178807947019867
# best_params :  {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.125}

# %%
df = pd.DataFrame(res)
df.to_csv('OCSVM_mask.csv')
