# %%
from deep_svdd import BaseSVDD
from matplotlib import pyplot as plt
import numpy as np

# %%
from pyod.utils.data import generate_data

# %%
n_train = 100  # number of training points
n_test = 10  # number of testing points
n_features = 2  # number of features

# Generate sample data
X_train, X_test, y_train, y_test = generate_data(n_train=n_train, n_test=n_test, n_features=n_features)
X_train/=np.max(X_train)

# %%
X_0 = X_train[y_train == 0]
X_1 = X_train[y_train == 1]
Y_0 = y_train[y_train == 0]
Y_1 = y_train[y_train == 1]

# %%
plt.scatter(X_0[:,0], X_0[:,1])
# plt.scatter(X_1[:,0], X_1[:,1])

# %%
y_train[y_train == 1] = -1
y_train[y_train == 0] = 1

# %%
y = y_train.reshape(100,1)

# %%
svdd = BaseSVDD(C=0.9)
svdd.fit(X_train, y)
# Out:
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 0.0554 seconds
# kernel function      = rbf
# iterations           = 10
# radius               = 0.6919
# number of samples    = 100
# number of features   = 2
# number of SVs        = 4
# ratio of SVs         = 4.0000 %
# accuracy             = 98.0000 %
# BaseSVDD(C=[0.9, 0.2], gamma=6.688631533239445)

# %%
svdd.center
# Out:
# array([[0.76031852, 0.761319  ]])

# %%
plt.scatter(X_0[:,0], X_0[:,1], c='blue')
plt.scatter(X_1[:,0], X_1[:,1], c='red')
circle = plt.Circle((0.76031852, 0.761319), 0.6919, fill=False, color='black')
plt.gca().add_patch(circle)

# プロットの設定
plt.show()
