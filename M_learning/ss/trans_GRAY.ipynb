# %%
from PIL import Image
import os

# 入力フォルダと出力フォルダを指定
input_folder = "bottle/train/good"
output_folder = "bottle_gray/train/good"

# 出力フォルダが存在しない場合は作成
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 入力フォルダ内の画像ファイルを取得
image_files = [f for f in os.listdir(input_folder) if f.endswith(('.png'))]

# すべての画像をグレースケールに変換して保存
for image_file in image_files:
    image_path = os.path.join(input_folder, image_file)
    output_path = os.path.join(output_folder, image_file)

    try:
        # 画像を開く
        img = Image.open(image_path)

        # グレースケールに変換
        img_gray = img.convert("L")

        # グレースケール画像を保存
        img_gray.save(output_path)

        print(f"{image_file} を変換して保存しました。")

    except Exception as e:
        print(f"{image_file} の変換中にエラーが発生しました: {str(e)}")
# Out:
# 000.png を変換して保存しました。
# 001.png を変換して保存しました。
# 002.png を変換して保存しました。
# 003.png を変換して保存しました。
# 004.png を変換して保存しました。
# 005.png を変換して保存しました。
# 006.png を変換して保存しました。
# 007.png を変換して保存しました。
# 008.png を変換して保存しました。
# 009.png を変換して保存しました。
# 010.png を変換して保存しました。
# 011.png を変換して保存しました。
# 012.png を変換して保存しました。
# 013.png を変換して保存しました。
# 014.png を変換して保存しました。
# 015.png を変換して保存しました。
# 016.png を変換して保存しました。
# 017.png を変換して保存しました。
# 018.png を変換して保存しました。
# 019.png を変換して保存しました。
# 020.png を変換して保存しました。
# 021.png を変換して保存しました。
# 022.png を変換して保存しました。
# 023.png を変換して保存しました。
# 024.png を変換して保存しました。
# 025.png を変換して保存しました。
# 026.png を変換して保存しました。
# 027.png を変換して保存しました。
# 028.png を変換して保存しました。
# 029.png を変換して保存しました。
# 030.png を変換して保存しました。
# 031.png を変換して保存しました。
# 032.png を変換して保存しました。
# 033.png を変換して保存しました。
# 034.png を変換して保存しました。
# 035.png を変換して保存しました。
# 036.png を変換して保存しました。
# 037.png を変換して保存しました。
# 038.png を変換して保存しました。
# 039.png を変換して保存しました。
# 040.png を変換して保存しました。
# 041.png を変換して保存しました。
# 042.png を変換して保存しました。
# 043.png を変換して保存しました。
# 044.png を変換して保存しました。
# 045.png を変換して保存しました。
# 046.png を変換して保存しました。
# 047.png を変換して保存しました。
# 048.png を変換して保存しました。
# 049.png を変換して保存しました。
# 050.png を変換して保存しました。
# 051.png を変換して保存しました。
# 052.png を変換して保存しました。
# 053.png を変換して保存しました。
# 054.png を変換して保存しました。
# 055.png を変換して保存しました。
# 056.png を変換して保存しました。
# 057.png を変換して保存しました。
# 058.png を変換して保存しました。
# 059.png を変換して保存しました。
# 060.png を変換して保存しました。
# 061.png を変換して保存しました。
# 062.png を変換して保存しました。
# 063.png を変換して保存しました。
# 064.png を変換して保存しました。
# 065.png を変換して保存しました。
# 066.png を変換して保存しました。
# 067.png を変換して保存しました。
# 068.png を変換して保存しました。
# 069.png を変換して保存しました。
# 070.png を変換して保存しました。
# 071.png を変換して保存しました。
# 072.png を変換して保存しました。
# 073.png を変換して保存しました。
# 074.png を変換して保存しました。
# 075.png を変換して保存しました。
# 076.png を変換して保存しました。
# 077.png を変換して保存しました。
# 078.png を変換して保存しました。
# 079.png を変換して保存しました。
# 080.png を変換して保存しました。
# 081.png を変換して保存しました。
# 082.png を変換して保存しました。
# 083.png を変換して保存しました。
# 084.png を変換して保存しました。
# 085.png を変換して保存しました。
# 086.png を変換して保存しました。
# 087.png を変換して保存しました。
# 088.png を変換して保存しました。
# 089.png を変換して保存しました。
# 090.png を変換して保存しました。
# 091.png を変換して保存しました。
# 092.png を変換して保存しました。
# 093.png を変換して保存しました。
# 094.png を変換して保存しました。
# 095.png を変換して保存しました。
# 096.png を変換して保存しました。
# 097.png を変換して保存しました。
# 098.png を変換して保存しました。
# 099.png を変換して保存しました。
# 100.png を変換して保存しました。
# 101.png を変換して保存しました。
# 102.png を変換して保存しました。
# 103.png を変換して保存しました。
# 104.png を変換して保存しました。
# 105.png を変換して保存しました。
# 106.png を変換して保存しました。
# 107.png を変換して保存しました。
# 108.png を変換して保存しました。
# 109.png を変換して保存しました。
# 110.png を変換して保存しました。
# 111.png を変換して保存しました。
# 112.png を変換して保存しました。
# 113.png を変換して保存しました。
# 114.png を変換して保存しました。
# 115.png を変換して保存しました。
# 116.png を変換して保存しました。
# 117.png を変換して保存しました。
# 118.png を変換して保存しました。
# 119.png を変換して保存しました。
# 120.png を変換して保存しました。
# 121.png を変換して保存しました。
# 122.png を変換して保存しました。
# 123.png を変換して保存しました。
# 124.png を変換して保存しました。
# 125.png を変換して保存しました。
# 126.png を変換して保存しました。
# 127.png を変換して保存しました。
# 128.png を変換して保存しました。
# 129.png を変換して保存しました。
# 130.png を変換して保存しました。
# 131.png を変換して保存しました。
# 132.png を変換して保存しました。
# 133.png を変換して保存しました。
# 134.png を変換して保存しました。
# 135.png を変換して保存しました。
# 136.png を変換して保存しました。
# 137.png を変換して保存しました。
# 138.png を変換して保存しました。
# 139.png を変換して保存しました。
# 140.png を変換して保存しました。
# 141.png を変換して保存しました。
# 142.png を変換して保存しました。
# 143.png を変換して保存しました。
# 144.png を変換して保存しました。
# 145.png を変換して保存しました。
# 146.png を変換して保存しました。
# 147.png を変換して保存しました。
# 148.png を変換して保存しました。
# 149.png を変換して保存しました。
# 150.png を変換して保存しました。
# 151.png を変換して保存しました。
# 152.png を変換して保存しました。
# 153.png を変換して保存しました。
# 154.png を変換して保存しました。
# 155.png を変換して保存しました。
# 156.png を変換して保存しました。
# 157.png を変換して保存しました。
# 158.png を変換して保存しました。
# 159.png を変換して保存しました。
# 160.png を変換して保存しました。
# 161.png を変換して保存しました。
# 162.png を変換して保存しました。
# 163.png を変換して保存しました。
# 164.png を変換して保存しました。
# 165.png を変換して保存しました。
# 166.png を変換して保存しました。
# 167.png を変換して保存しました。
# 168.png を変換して保存しました。
# 169.png を変換して保存しました。
# 170.png を変換して保存しました。
# 171.png を変換して保存しました。
# 172.png を変換して保存しました。
# 173.png を変換して保存しました。
# 174.png を変換して保存しました。
# 175.png を変換して保存しました。
# 176.png を変換して保存しました。
# 177.png を変換して保存しました。
# 178.png を変換して保存しました。
# 179.png を変換して保存しました。
# 180.png を変換して保存しました。
# 181.png を変換して保存しました。
# 182.png を変換して保存しました。
# 183.png を変換して保存しました。
# 184.png を変換して保存しました。
# 185.png を変換して保存しました。
# 186.png を変換して保存しました。
# 187.png を変換して保存しました。
# 188.png を変換して保存しました。
# 189.png を変換して保存しました。
# 190.png を変換して保存しました。
# 191.png を変換して保存しました。
# 192.png を変換して保存しました。
# 193.png を変換して保存しました。
# 194.png を変換して保存しました。
# 195.png を変換して保存しました。
# 196.png を変換して保存しました。
# 197.png を変換して保存しました。
# 198.png を変換して保存しました。
# 199.png を変換して保存しました。
# 200.png を変換して保存しました。
# 201.png を変換して保存しました。
# 202.png を変換して保存しました。
# 203.png を変換して保存しました。
# 204.png を変換して保存しました。
# 205.png を変換して保存しました。
# 206.png を変換して保存しました。
# 207.png を変換して保存しました。
# 208.png を変換して保存しました。
